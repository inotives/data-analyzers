# %%
import pandas as pd
import matplotlib.pyplot as plt

crypto_ohlcv_weekly = pd.read_csv('../data/_OUTPUTS/OHLCV_WEEKLY_CRYPTO_ANALYSIS.csv')
crypto_ohlcv_weekly.head()
# Out:
#    index metric_date          open          high           low         close  \
# 0    522  2024-01-07  42280.235276  45899.706355  40813.534868  43943.097229
# 1    523  2024-01-14  43948.706955  48969.371400  41724.613725  41796.269606
# 2    524  2024-01-21  41715.066527  43566.274924  40297.457858  41545.783514
# 3    525  2024-01-28  41553.652691  42797.177359  38521.893888  42035.594372
# 4    526  2024-02-04  42030.915380  43838.946844  41818.331086  42583.582920
#
#          volume    market_cap  mcap_weekly_growth  mcap_weekly_change  \
# 0  2.023118e+11  8.609518e+11            4.003404        3.314063e+10
# 1  2.599718e+11  8.191599e+11           -4.854159       -4.179197e+10
# 2  1.391358e+11  8.144890e+11           -0.570206       -4.670897e+09
# 3  1.553146e+11  8.243879e+11            1.215351        9.898903e+09
# 4  1.351842e+11  8.354218e+11            1.338435        1.103389e+10
#
#     crypto         type
# 0  Bitcoin  cryptocoins
# 1  Bitcoin  cryptocoins
# ...
